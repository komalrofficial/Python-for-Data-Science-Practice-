# %%
print("Hello")
# Out:
# Hello

# %%
print("Welcome to Python programming Komal!")
# Out:
# Welcome to Python programming Komal!

# %%
("Welcome to Python programming Komal!")
# Out:
# 'Welcome to Python programming Komal!'

# %%
2+3
# Out:
# 5
