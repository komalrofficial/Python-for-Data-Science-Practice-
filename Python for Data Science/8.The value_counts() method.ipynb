# %%
import pandas as pd

# %%
exam=pd.read_csv(r"D:\Python\Python for Data Science\StudentsPerformance.csv")
exam.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# counting gender elements

# len function
len(exam['gender'])
# .count() method
exam['gender'].count()
# Out:
# np.int64(1000)

# %%
# counting gender elements by category
exam['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
# return the relative frequency (divide all values by the sum of values)
exam['gender'].value_counts(normalize=True)
# Out:
# gender
# female    0.518
# male      0.482
# Name: proportion, dtype: float64

# %%
# counting "parental level of education" elements by category
exam['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
# counting "parental level of education" elements by category
exam['lunch'].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
# counting "parental level of education" elements by category
exam['test preparation course'].value_counts()
# Out:
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64

# %%
# return the relative frequency and round to 2 decimals
exam['parental level of education'].value_counts(normalize=True).round(2)
# Out:
# parental level of education
# some college          0.23
# associate's degree    0.22
# high school           0.20
# some high school      0.18
# bachelor's degree     0.12
# master's degree       0.06
# Name: proportion, dtype: float64

# %%
# return the relative frequency and round to 2 decimals
exam['parental level of education'].value_counts(normalize=True).round(3)
# Out:
# parental level of education
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: proportion, dtype: float64

# %%
# return the relative frequency and round to 2 decimals
exam['parental level of education'].value_counts(normalize=True).round(4)
# Out:
# parental level of education
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: proportion, dtype: float64

# %%
exam['lunch'].value_counts(normalize=True).round(2)
# Out:
# lunch
# standard        0.64
# free/reduced    0.36
# Name: proportion, dtype: float64

# %%
exam['math score'].value_counts(normalize=True)
# Out:
# math score
# 65    0.036
# 62    0.035
# 69    0.032
# 59    0.032
# 73    0.027
#       ...
# 24    0.001
# 26    0.001
# 19    0.001
# 23    0.001
# 8     0.001
# Name: proportion, Length: 81, dtype: float64

# %%
exam['reading score'].value_counts(normalize=True)
# Out:
# reading score
# 72    0.034
# 74    0.033
# 64    0.032
# 73    0.030
# 67    0.030
#       ...
# 17    0.001
# 26    0.001
# 28    0.001
# 23    0.001
# 40    0.001
# Name: proportion, Length: 72, dtype: float64
