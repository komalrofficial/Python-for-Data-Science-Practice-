# %%
import pandas as pd
import numpy as np

# %%
#creating an array

komal=np.array([[46,58],[66,70],[57,89],[86,91]])

# %%
#creating a dataframe
df=pd.DataFrame(komal,index=['row1','row2','row3','row4'],
                columns=['col1','col2'])

# %%
df
# Out:
#       col1  col2
# row1    46    58
# row2    66    70
# row3    57    89
# row4    86    91

# %%
komal=[[46,58],[66,70],[57,89],[86,91]]

# %%
df=pd.DataFrame(komal,index=['row1','row2','row3','row4'],
                columns=['col1','col2'])

# %%
df
# Out:
#       col1  col2
# row1    46    58
# row2    66    70
# row3    57    89
# row4    86    91

# %%
import pandas as pd
import numpy as np

# %%
#by dictionery

states=["maharashtra","gujarat","tamilnadu","karnataka"]
districts=["nagpur", "surat", "coimbatur", "banglore"]

# %%
dict_states={
    "states":states,
    "districts":districts,
    }

# %%
komal=pd.DataFrame(dict_states)

# %%
komal
# Out:
#         states  districts
# 0  maharashtra     nagpur
# 1      gujarat      surat
# 2    tamilnadu  coimbatur
# 3    karnataka   banglore
