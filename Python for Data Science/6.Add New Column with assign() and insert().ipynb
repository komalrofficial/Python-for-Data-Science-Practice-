# %%
import pandas as pd

# %%
komal=pd.read_csv(r"D:\Python\Python for Data Science\StudentsPerformance.csv")
komal.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
import numpy as np

# %%
score1 = np.random.randint(1, 100, size=1000)
score2 = np.random.randint(1, 100, size=1000)

# %%
# create a series using the random numbers
series1 = pd.Series(score1, index=np.arange(0, 1000))
series2 = pd.Series(score2, index=np.arange(0, 1000))

# %%
# using assign() to add multiple columns
komal = komal.assign(score1=series1, score2=series2)

# %%
komal
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74      20
# 1                 completed          69             90             88      20
# 2                      none          90             95             93      29
# 3                      none          47             57             44      76
# 4                      none          76             78             75      96
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      44
# 996                    none          62             55             55      42
# 997               completed          59             71             65      76
# 998               completed          68             78             77      54
# 999                    none          77             86             86      99
#
#      score2
# 0        82
# 1        12
# 2        22
# 3        52
# 4        60
# ..      ...
# 995      91
# 996      25
# 997      91
# 998      99
# 999      13
#
# [1000 rows x 10 columns]

# %%
# using insert() to add a column at a specific position
komal.insert(1, 'test', series1)

# %%
komal
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    20        group B           bachelor's degree      standard
# 1    female    20        group C                some college      standard
# 2    female    29        group B             master's degree      standard
# 3      male    76        group A          associate's degree  free/reduced
# 4      male    96        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    44        group E             master's degree      standard
# 996    male    42        group C                 high school  free/reduced
# 997  female    76        group C                 high school  free/reduced
# 998  female    54        group D                some college      standard
# 999  female    99        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74      20
# 1                 completed          69             90             88      20
# 2                      none          90             95             93      29
# 3                      none          47             57             44      76
# 4                      none          76             78             75      96
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      44
# 996                    none          62             55             55      42
# 997               completed          59             71             65      76
# 998               completed          68             78             77      54
# 999                    none          77             86             86      99
#
#      score2
# 0        82
# 1        12
# 2        22
# 3        52
# 4        60
# ..      ...
# 995      91
# 996      25
# 997      91
# 998      99
# 999      13
#
# [1000 rows x 11 columns]

# %%
import pandas as pd

# %%
minal=pd.read_csv(r"D:\Python\Python for Data Science\StudentsPerformance.csv")
minal.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
minal.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
import numpy as np

# %%
# create random numbers for our new score columns
score1 = np.random.randint(1, 100, size=1000)
score2 = np.random.randint(1, 100, size=1000)

# %%
# create a series using the random numbers
series1 = pd.Series(score1, index=np.arange(0, 1000))
series2 = pd.Series(score2, index=np.arange(0, 1000))

# %%
# using assign() to add multiple columns
minal = minal.assign(score1=series1, score2=series2)

# %%
minal
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             74       1
# 1                 completed          69             90             88      13
# 2                      none          90             95             93      44
# 3                      none          47             57             44      73
# 4                      none          76             78             75      46
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             95      44
# 996                    none          62             55             55      34
# 997               completed          59             71             65      23
# 998               completed          68             78             77      58
# 999                    none          77             86             86      96
#
#      score2
# 0        37
# 1        20
# 2        31
# 3        91
# 4        59
# ..      ...
# 995      28
# 996      65
# 997      28
# 998      30
# 999      31
#
# [1000 rows x 10 columns]

# %%
# using insert() to add a column at a specific position
minal.insert(3, 'test3', series1)

# %%
minal
# Out:
#      gender  test race/ethnicity  test3 parental level of education  \
# 0    female     1        group B      1           bachelor's degree
# 1    female    13        group C     13                some college
# 2    female    44        group B     44             master's degree
# 3      male    73        group A     73          associate's degree
# 4      male    46        group C     46                some college
# ..      ...   ...            ...    ...                         ...
# 995  female    44        group E     44             master's degree
# 996    male    34        group C     34                 high school
# 997  female    23        group C     23                 high school
# 998  female    58        group D     58                some college
# 999  female    96        group D     96                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          72             72
# 1        standard               completed          69             90
# 2        standard                    none          90             95
# 3    free/reduced                    none          47             57
# 4        standard                    none          76             78
# ..            ...                     ...         ...            ...
# 995      standard               completed          88             99
# 996  free/reduced                    none          62             55
# 997  free/reduced               completed          59             71
# 998      standard               completed          68             78
# 999  free/reduced                    none          77             86
#
#      writing score  score1  score2
# 0               74       1      37
# 1               88      13      20
# 2               93      44      31
# 3               44      73      91
# 4               75      46      59
# ..             ...     ...     ...
# 995             95      44      28
# 996             55      34      65
# 997             65      23      28
# 998             77      58      30
# 999             86      96      31
#
# [1000 rows x 12 columns]

# %%
# using insert() to add a column at a specific position
minal.insert(4, 'test4', series1)
minal
# Out:
#      gender  test race/ethnicity  test3  test4 parental level of education  \
# 0    female     1        group B      1      1           bachelor's degree
# 1    female    13        group C     13     13                some college
# 2    female    44        group B     44     44             master's degree
# 3      male    73        group A     73     73          associate's degree
# 4      male    46        group C     46     46                some college
# ..      ...   ...            ...    ...    ...                         ...
# 995  female    44        group E     44     44             master's degree
# 996    male    34        group C     34     34                 high school
# 997  female    23        group C     23     23                 high school
# 998  female    58        group D     58     58                some college
# 999  female    96        group D     96     96                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          72             72
# 1        standard               completed          69             90
# 2        standard                    none          90             95
# 3    free/reduced                    none          47             57
# 4        standard                    none          76             78
# ..            ...                     ...         ...            ...
# 995      standard               completed          88             99
# 996  free/reduced                    none          62             55
# 997  free/reduced               completed          59             71
# 998      standard               completed          68             78
# 999  free/reduced                    none          77             86
#
#      writing score  score1  score2
# 0               74       1      37
# 1               88      13      20
# 2               93      44      31
# 3               44      73      91
# 4               75      46      59
# ..             ...     ...     ...
# 995             95      44      28
# 996             55      34      65
# 997             65      23      28
# 998             77      58      30
# 999             86      96      31
#
# [1000 rows x 13 columns]

# %%
import pandas as pd

data = [2, 4, 4, 4, 6]
df = pd.Series(data)

# Sample standard deviation (Default: ddof=1)
sample_sd = df.std()
print(f"Pandas Sample SD: {sample_sd:.3f}")  # Output: 1.414
# Out:
# Pandas Sample SD: 1.414
